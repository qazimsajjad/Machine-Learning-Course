# %% [markdown]
# **Simple Linear Regression** - Gradient Descent Implementation
# * Manual Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.loadtxt('ex2x.dat', dtype=np.float32)
y = np.loadtxt('ex2y.dat', dtype=np.float32)

# %%
x, y
# Out:
# (array([2.0658746, 2.3684087, 2.5399928, 2.5420804, 2.549079 , 2.786688 ,
#         2.9116826, 3.035627 , 3.1146696, 3.158239 , 3.3275945, 3.3793166,
#         3.4122007, 3.4215822, 3.5315733, 3.6393   , 3.6732538, 3.9256463,
#         4.049865 , 4.248335 , 4.344005 , 4.382653 , 4.4230604, 4.6102443,
#         4.6881185, 4.977733 , 5.035997 , 5.068454 , 5.416149 , 5.4395623,
#         5.456321 , 5.5698457, 5.601573 , 5.687762 , 5.72156  , 5.8538914,
#         6.1978025, 6.3510942, 6.4797034, 6.738379 , 6.8637686, 7.022339 ,
#         7.0782375, 7.151423 , 7.4664025, 7.5973873, 7.7440715, 7.7729664,
#         7.8264513, 7.9306355], dtype=float32),
#  array([0.7791893 , 0.9159676 , 0.9053835 , 0.9056614 , 0.9389889 ,
#         0.9668474 , 0.9643682 , 0.9144594 , 0.93933946, 0.9607497 ,
#         0.8983709 , 0.9120974 , 0.942385  , 0.9662458 , 1.05265   ,
#         1.0143791 , 0.95969427, 0.96853715, 1.0766065 , 1.1454978 ,
#         1.0340625 , 1.0070009 , 0.96683645, 1.0895919 , 1.0634462 ,
#         1.1237239 , 1.0323374 , 1.0874453 , 1.0702988 , 1.1606493 ,
#         1.0778037 , 1.1069758 , 1.0971875 , 1.1648602 , 1.1411796 ,
#         1.0844156 , 1.1252493 , 1.116834  , 1.197079  , 1.2069463 ,
#         1.1251045 , 1.1235672 , 1.213283  , 1.2522652 , 1.2497065 ,
#         1.1799706 , 1.1897299 , 1.3029934 , 1.2601134 , 1.2562267 ],
#        dtype=float32))

# %%
plt.scatter(x, y, marker='x', c='r')
plt.title("Data")
plt.show()

# %%
x.shape[0]
# Out:
# 50

# %%
X = np.ones((x.shape[0], 2))

# %%
X[:, 1] = x

# %%
X
# Out:
# array([[1.        , 2.06587458],
#        [1.        , 2.36840868],
#        [1.        , 2.53999281],
#        [1.        , 2.5420804 ],
#        [1.        , 2.54907894],
#        [1.        , 2.78668809],
#        [1.        , 2.91168261],
#        [1.        , 3.03562689],
#        [1.        , 3.11466956],
#        [1.        , 3.15823889],
#        [1.        , 3.32759452],
#        [1.        , 3.37931657],
#        [1.        , 3.41220069],
#        [1.        , 3.42158222],
#        [1.        , 3.5315733 ],
#        [1.        , 3.63930011],
#        [1.        , 3.67325377],
#        [1.        , 3.92564631],
#        [1.        , 4.04986477],
#        [1.        , 4.24833488],
#        [1.        , 4.34400511],
#        [1.        , 4.38265324],
#        [1.        , 4.42306042],
#        [1.        , 4.61024427],
#        [1.        , 4.68811846],
#        [1.        , 4.97773314],
#        [1.        , 5.03599691],
#        [1.        , 5.06845379],
#        [1.        , 5.41614914],
#        [1.        , 5.43956232],
#        [1.        , 5.45632076],
#        [1.        , 5.56984568],
#        [1.        , 5.60157299],
#        [1.        , 5.68776178],
#        [1.        , 5.72156   ],
#        [1.        , 5.85389137],
#        [1.        , 6.19780254],
#        [1.        , 6.35109425],
#        [1.        , 6.47970343],
#        [1.        , 6.738379  ],
#        [1.        , 6.86376858],
#        [1.        , 7.02233887],
#        [1.        , 7.07823753],
#        [1.        , 7.15142298],
#        [1.        , 7.46640253],
#        [1.        , 7.59738731],
#        [1.        , 7.74407148],
#        [1.        , 7.77296638],
#        [1.        , 7.8264513 ],
#        [1.        , 7.93063545]])

# %%
def hypothesis(x, w):
    return np.dot(x, w)

# %%
def cost(x, y, w):
    return 1/(2*x.shape[0]) * sum(hypothesis(x, w) - y)**2

# %%
def gradient(x, y, w):
    return 1/(x.shape[0]) * x.T.dot(hypothesis(x, w) - y)

# %%
w = np.array([0, 0])
costVal = []
epochs = []
for i in range(1, 300):
    costVal.append(cost(X, y, w))
    w = w - 0.0003 * gradient(X, y, w)
    epochs.append(i)

# %%
w
# Out:
# array([0.03912056, 0.17725055])

# %%
plt.plot(epochs, costVal)
plt.title("Epochs vs. Cost")
plt.xlabel("Epochs")
plt.ylabel("Cost")
plt.show()

# %%
plt.scatter(x, y, marker='x', c='r', label= ("Data"))
plt.plot(x, hypothesis(X, w), label= ("fitted line"))
plt.title("Data vs. Fitted Line")
plt.legend()
plt.show()

# %% [markdown]
# ---
# Thank You
